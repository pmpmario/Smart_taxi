# %% [markdown]
# # Result Example (Output)
#
# {
#   "Date": "14/11/2024",
#   "Pick Up Time": "15:21",
#   "Pick Up Location": "Al Rigga Metro",
#   "Drop Off Time": "15:51",
#   "Drop Off Location": "Dubai Mall",
#   "Total Amount": "32.50",
#   "Payment Method": "Visa"
# }
